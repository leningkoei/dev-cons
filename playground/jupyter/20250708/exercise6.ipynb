# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("exercise6/web信号.xls")
data
# Out:
#           编号                                                 内容
# 0          1  2025-06-20 09:20:05      城南.景蓬道站 景4102HK负2 房热一...
# 1          2  2025-06-20 09:20:29      553KB3负4故障合并 值 遥信封锁分 ...
# 2          3  2025-06-20 09:20:48      城南.景蓬道站 景6102HK负5 房热二...
# 3          4  2025-06-20 09:21:19      城南.景蓬道站 景6102HK负5 房热二...
# 4          5  2025-06-20 09:21:44      NK115负6 国民饭店平13线 遥信值 ...
# ...      ...                                                ...
# 10480  10481  2025-06-20 16:49:01      上83315HK负5故障合并 值 遥信确认...
# 10481  10482  2025-06-20 16:50:16      城南.纪庄子站 纪3406负2 世纪花园二...
# 10482  10483  2025-06-20 16:50:24      上83315HK负1故障合并 值 遥信确认...
# 10483  10484  2025-06-20 16:54:17      城南.微山路站 微12KB7负6 鸿富微1...
# 10484  10485  2025-06-20 16:59:45      城南.微山路站 微41KB1负6 后三合微...
#
# [10485 rows x 2 columns]

# %%
# 从内容中提取时间并增加一列存储至data
data["时间"] = data["内容"].str.extract(r'(\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2})')
data["时间"] = pd.to_datetime(data["时间"])
data
# Out:
#           编号                                                 内容  \
# 0          1  2025-06-20 09:20:05      城南.景蓬道站 景4102HK负2 房热一...
# 1          2  2025-06-20 09:20:29      553KB3负4故障合并 值 遥信封锁分 ...
# 2          3  2025-06-20 09:20:48      城南.景蓬道站 景6102HK负5 房热二...
# 3          4  2025-06-20 09:21:19      城南.景蓬道站 景6102HK负5 房热二...
# 4          5  2025-06-20 09:21:44      NK115负6 国民饭店平13线 遥信值 ...
# ...      ...                                                ...
# 10480  10481  2025-06-20 16:49:01      上83315HK负5故障合并 值 遥信确认...
# 10481  10482  2025-06-20 16:50:16      城南.纪庄子站 纪3406负2 世纪花园二...
# 10482  10483  2025-06-20 16:50:24      上83315HK负1故障合并 值 遥信确认...
# 10483  10484  2025-06-20 16:54:17      城南.微山路站 微12KB7负6 鸿富微1...
# 10484  10485  2025-06-20 16:59:45      城南.微山路站 微41KB1负6 后三合微...
#
#                        时间
# 0     2025-06-20 09:20:05
# 1     2025-06-20 09:20:29
# 2     2025-06-20 09:20:48
# 3     2025-06-20 09:21:19
# 4     2025-06-20 09:21:44
# ...                   ...
# ...

# %%
mask = data["时间"] < "2025-06-20 09:21:05"
mask
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 10480    False
# 10481    False
# 10482    False
# 10483    False
# 10484    False
# Name: 时间, Length: 10485, dtype: bool

# %%
data1 = data[mask]
data1
# Out:
#    编号                                                 内容                  时间
# 0   1  2025-06-20 09:20:05      城南.景蓬道站 景4102HK负2 房热一... 2025-06-20 09:20:05
# 1   2  2025-06-20 09:20:29      553KB3负4故障合并 值 遥信封锁分 ... 2025-06-20 09:20:29
# 2   3  2025-06-20 09:20:48      城南.景蓬道站 景6102HK负5 房热二... 2025-06-20 09:20:48

# %%
data["开关"] = data["内容"].str.extract(r"城南.* (.*负\d+?)")
data
# Out:
#           编号                                                 内容  \
# 0          1  2025-06-20 09:20:05      城南.景蓬道站 景4102HK负2 房热一...
# 1          2  2025-06-20 09:20:29      553KB3负4故障合并 值 遥信封锁分 ...
# 2          3  2025-06-20 09:20:48      城南.景蓬道站 景6102HK负5 房热二...
# 3          4  2025-06-20 09:21:19      城南.景蓬道站 景6102HK负5 房热二...
# 4          5  2025-06-20 09:21:44      NK115负6 国民饭店平13线 遥信值 ...
# ...      ...                                                ...
# 10480  10481  2025-06-20 16:49:01      上83315HK负5故障合并 值 遥信确认...
# 10481  10482  2025-06-20 16:50:16      城南.纪庄子站 纪3406负2 世纪花园二...
# 10482  10483  2025-06-20 16:50:24      上83315HK负1故障合并 值 遥信确认...
# 10483  10484  2025-06-20 16:54:17      城南.微山路站 微12KB7负6 鸿富微1...
# 10484  10485  2025-06-20 16:59:45      城南.微山路站 微41KB1负6 后三合微...
#
#                        时间         开关
# 0     2025-06-20 09:20:05  景4102HK负2
# 1     2025-06-20 09:20:29        NaN
# 2     2025-06-20 09:20:48  景6102HK负5
# 3     2025-06-20 09:21:19  景6102HK负5
# ...
